# %%
from selenium import webdriver
from selenium.webdriver.chrome import service as Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time
import re
import random
import json
from paho.mqtt import client as mqtt_client
from datetime import datetime
url = "http://www.berliner-feuerwehr.de"

#chrome driver  
options = Options()
options.headless = True
service = Service.Service(executable_path="driver/chromedriver")  


#### MQTT ###
broker = '192.168.188.32'
port = 1883
topic = "einsatzzahlen"
client_id = f'python-mqtt-{random.randint(0, 1000)}'
# username = 'emqx'
# password = 'public'

def connect_mqtt():
    def on_connect(client, userdata, flags, rc):
        if rc == 0:
            print("Connected to MQTT Broker!")
        else:
            print("Failed to connect, return code %d\n", rc)
    # Set Connecting Client ID
    client = mqtt_client.Client(client_id)
    #client.username_pw_set(username, password)
    client.on_connect = on_connect
    client.connect(broker, port)
    #client.enable_logger(logger=None)
    return client

def publish(client,data):
    now = datetime.now()
    current_time = now.strftime("%H:%M:%S:%f")
    
         #time.sleep(10)  # Intervall bis zur nächsten Nachricht #
    msg = f'{data}'
    result = client.publish(topic, msg)
    
    # result: [0, 1]
    status = result[0]
    if status == 0:
        print(f"{current_time} Send `{msg}` to topic `{topic}`")
    else:
        print(f"Failed to send message to topic {topic}")

def data_extract(input_data):
    regex = '"[0-9]+"gm'
    data = re.findall('[0-9]+',input_data)
    einsatz ={"Brandbekämpfung": data[3], "Technische Hilfeleistung": data[4], "Rettungsdienst":data[5]}
    return json.dumps(einsatz, ensure_ascii=False)

def main():
    client = connect_mqtt()
    client.loop_start()

    run = True
    while run:
        try:
            driver = webdriver.Chrome(service=service, options=options)
            driver.get(url=url)
            zahlen_response = driver.find_element(By.ID, "einsatzahlen").text
            driver.close()
            #print(zahlen_response)
            publish(client=client, data=data_extract(zahlen_response))
            #print(time.asctime(), " " , data_extract(zahlen_response))
            time.sleep(60)
            
        except:
            pass

# %%
if __name__ == "__main__":
     main()
# Out:
# Connected to MQTT Broker!
# 20:51:40:850338 Send `{"Brandbekämpfung": "42", "Technische Hilfeleistung": "109", "Rettungsdienst": "1177"}` to topic `einsatzzahlen`
# 20:52:52:740010 Send `{"Brandbekämpfung": "42", "Technische Hilfeleistung": "109", "Rettungsdienst": "1181"}` to topic `einsatzzahlen`
# 20:54:03:930973 Send `{"Brandbekämpfung": "42", "Technische Hilfeleistung": "110", "Rettungsdienst": "1181"}` to topic `einsatzzahlen`
# 21:00:11:568254 Send `{"Brandbekämpfung": "42", "Technische Hilfeleistung": "110", "Rettungsdienst": "1192"}` to topic `einsatzzahlen`
# 21:01:15:421818 Send `{"Brandbekämpfung": "43", "Technische Hilfeleistung": "110", "Rettungsdienst": "1193"}` to topic `einsatzzahlen`
# 21:02:18:968768 Send `{"Brandbekämpfung": "43", "Technische Hilfeleistung": "110", "Rettungsdienst": "1196"}` to topic `einsatzzahlen`
# 21:03:23:362307 Send `{"Brandbekämpfung": "43", "Technische Hilfeleistung": "110", "Rettungsdienst": "1199"}` to topic `einsatzzahlen`
# 21:04:26:056209 Send `{"Brandbekämpfung": "43", "Technische Hilfeleistung": "110", "Rettungsdienst": "1200"}` to topic `einsatzzahlen`
# 21:05:28:765708 Send `{"Brandbekämpfung": "43", "Technische Hilfeleistung": "110", "Rettungsdienst": "1200"}` to topic `einsatzzahlen`
# 21:06:31:751370 Send `{"Brandbekämpfung": "43", "Technische Hilfeleistung": "110", "Rettungsdienst": "1202"}` to topic `einsatzzahlen`
# 21:07:34:670502 Send `{"Brandbekämpfung": "43", "Technische Hilfeleistung": "110", "Rettungsdienst": "1203"}` to topic `einsatzzahlen`
# 21:08:38:343412 Send `{"Brandbekämpfung": "43", "Technische Hilfeleistung": "110", "Rettungsdienst": "1204"}` to topic `einsatzzahlen`
# 21:09:41:606547 Send `{"Brandbekämpfung": "43", "Technische Hilfeleistung": "111", "Rettungsdienst": "1207"}` to topic `einsatzzahlen`
# 21:10:44:161783 Send `{"Brandbekämpfung": "43", "Technische Hilfeleistung": "111", "Rettungsdienst": "1207"}` to topic `einsatzzahlen`
# 21:11:47:543937 Send `{"Brandbekämpfung": "43", "Technische Hilfeleistung": "112", "Rettungsdienst": "1208"}` to topic `einsatzzahlen`
# 21:12:53:931730 Send `{"Brandbekämpfung": "43", "Technische Hilfeleistung": "112", "Rettungsdienst": "1209"}` to topic `einsatzzahlen`
# 21:13:58:825711 Send `{"Brandbekämpfung": "43", "Technische Hilfeleistung": "113", "Rettungsdienst": "1209"}` to topic `einsatzzahlen`
# 21:15:05:399334 Send `{"Brandbekämpfung": "43", "Technische Hilfeleistung": "113", "Rettungsdienst": "1210"}` to topic `einsatzzahlen`
# 21:16:10:874588 Send `{"Brandbekämpfung": "43", "Technische Hilfeleistung": "113", "Rettungsdienst": "1210"}` to topic `einsatzzahlen`
# 21:17:13:354055 Send `{"Brandbekämpfung": "43", "Technische Hilfeleistung": "113", "Rettungsdienst": "1213"}` to topic `einsatzzahlen`
# 21:18:16:503275 Send `{"Brandbekämpfung": "43", "Technische Hilfeleistung": "113", "Rettungsdienst": "1215"}` to topic `einsatzzahlen`
# 21:19:18:950225 Send `{"Brandbekämpfung": "43", "Technische Hilfeleistung": "113", "Rettungsdienst": "1217"}` to topic `einsatzzahlen`
# 21:20:21:051683 Send `{"Brandbekämpfung": "43", "Technische Hilfeleistung": "113", "Rettungsdienst": "1218"}` to topic `einsatzzahlen`
# 21:21:23:415620 Send `{"Brandbekämpfung": "44", "Technische Hilfeleistung": "114", "Rettungsdienst": "1219"}` to topic `einsatzzahlen`
# 21:22:26:199352 Send `{"Brandbekämpfung": "45", "Technische Hilfeleistung": "114", "Rettungsdienst": "1221"}` to topic `einsatzzahlen`
# 21:23:28:540429 Send `{"Brandbekämpfung": "45", "Technische Hilfeleistung": "114", "Rettungsdienst": "1222"}` to topic `einsatzzahlen`
# 21:24:34:028821 Send `{"Brandbekämpfung": "45", "Technische Hilfeleistung": "114", "Rettungsdienst": "1225"}` to topic `einsatzzahlen`
# 21:25:36:644161 Send `{"Brandbekämpfung": "45", "Technische Hilfeleistung": "114", "Rettungsdienst": "1227"}` to topic `einsatzzahlen`
# 21:26:39:186411 Send `{"Brandbekämpfung": "45", "Technische Hilfeleistung": "114", "Rettungsdienst": "1227"}` to topic `einsatzzahlen`
# 21:27:41:699493 Send `{"Brandbekämpfung": "45", "Technische Hilfeleistung": "114", "Rettungsdienst": "1227"}` to topic `einsatzzahlen`
# 21:28:44:152489 Send `{"Brandbekämpfung": "45", "Technische Hilfeleistung": "114", "Rettungsdienst": "1227"}` to topic `einsatzzahlen`
# 21:29:46:828421 Send `{"Brandbekämpfung": "45", "Technische Hilfeleistung": "114", "Rettungsdienst": "1229"}` to topic `einsatzzahlen`
# 21:30:49:729753 Send `{"Brandbekämpfung": "45", "Technische Hilfeleistung": "114", "Rettungsdienst": "1229"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# 22:32:34:650620 Send `{"Brandbekämpfung": "48", "Technische Hilfeleistung": "116", "Rettungsdienst": "1305"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 22:42:54:147097 Send `{"Brandbekämpfung": "48", "Technische Hilfeleistung": "117", "Rettungsdienst": "1315"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 22:53:13:481345 Send `{"Brandbekämpfung": "48", "Technische Hilfeleistung": "117", "Rettungsdienst": "1327"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 23:03:31:917290 Send `{"Brandbekämpfung": "48", "Technische Hilfeleistung": "120", "Rettungsdienst": "1337"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 23:23:08:661591 Send `{"Brandbekämpfung": "50", "Technische Hilfeleistung": "121", "Rettungsdienst": "1356"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 23:33:29:045214 Send `{"Brandbekämpfung": "50", "Technische Hilfeleistung": "121", "Rettungsdienst": "1365"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 23:43:50:711069 Send `{"Brandbekämpfung": "50", "Technische Hilfeleistung": "121", "Rettungsdienst": "1376"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 23:54:11:411380 Send `{"Brandbekämpfung": "51", "Technische Hilfeleistung": "122", "Rettungsdienst": "1391"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 00:14:21:529251 Send `{"Brandbekämpfung": "0", "Technische Hilfeleistung": "2", "Rettungsdienst": "10"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# 01:18:40:665835 Send `{"Brandbekämpfung": "5", "Technische Hilfeleistung": "3", "Rettungsdienst": "61"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# Failed to send message to topic einsatzzahlen
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# 01:42:45:013056 Send `{"Brandbekämpfung": "5", "Technische Hilfeleistung": "3", "Rettungsdienst": "80"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 01:45:01:080771 Send `{"Brandbekämpfung": "5", "Technische Hilfeleistung": "3", "Rettungsdienst": "82"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 01:55:19:370232 Send `{"Brandbekämpfung": "5", "Technische Hilfeleistung": "3", "Rettungsdienst": "85"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# 02:38:31:944067 Send `{"Brandbekämpfung": "6", "Technische Hilfeleistung": "3", "Rettungsdienst": "113"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 02:48:53:804333 Send `{"Brandbekämpfung": "6", "Technische Hilfeleistung": "3", "Rettungsdienst": "119"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# 03:12:15:218648 Send `{"Brandbekämpfung": "6", "Technische Hilfeleistung": "4", "Rettungsdienst": "133"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 03:31:51:648643 Send `{"Brandbekämpfung": "7", "Technische Hilfeleistung": "4", "Rettungsdienst": "139"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# 03:42:11:719978 Send `{"Brandbekämpfung": "7", "Technische Hilfeleistung": "5", "Rettungsdienst": "143"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 03:52:30:860182 Send `{"Brandbekämpfung": "7", "Technische Hilfeleistung": "5", "Rettungsdienst": "145"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 04:02:49:979430 Send `{"Brandbekämpfung": "7", "Technische Hilfeleistung": "5", "Rettungsdienst": "149"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 04:15:33:540522 Send `{"Brandbekämpfung": "8", "Technische Hilfeleistung": "5", "Rettungsdienst": "162"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 04:25:52:972745 Send `{"Brandbekämpfung": "8", "Technische Hilfeleistung": "5", "Rettungsdienst": "169"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 04:36:12:094929 Send `{"Brandbekämpfung": "9", "Technische Hilfeleistung": "5", "Rettungsdienst": "173"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 04:46:31:620438 Send `{"Brandbekämpfung": "9", "Technische Hilfeleistung": "5", "Rettungsdienst": "174"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 04:56:51:602783 Send `{"Brandbekämpfung": "9", "Technische Hilfeleistung": "5", "Rettungsdienst": "177"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 05:16:27:777958 Send `{"Brandbekämpfung": "9", "Technische Hilfeleistung": "5", "Rettungsdienst": "188"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 05:26:47:999691 Send `{"Brandbekämpfung": "9", "Technische Hilfeleistung": "5", "Rettungsdienst": "195"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 05:37:07:354319 Send `{"Brandbekämpfung": "9", "Technische Hilfeleistung": "5", "Rettungsdienst": "200"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 05:47:26:523387 Send `{"Brandbekämpfung": "9", "Technische Hilfeleistung": "5", "Rettungsdienst": "203"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 06:07:02:993303 Send `{"Brandbekämpfung": "9", "Technische Hilfeleistung": "5", "Rettungsdienst": "207"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 06:17:21:274293 Send `{"Brandbekämpfung": "10", "Technische Hilfeleistung": "5", "Rettungsdienst": "212"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 06:22:40:697438 Send `{"Brandbekämpfung": "10", "Technische Hilfeleistung": "5", "Rettungsdienst": "213"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 06:33:01:547676 Send `{"Brandbekämpfung": "10", "Technische Hilfeleistung": "5", "Rettungsdienst": "220"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 06:52:35:943685 Send `{"Brandbekämpfung": "10", "Technische Hilfeleistung": "6", "Rettungsdienst": "236"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 07:02:54:745595 Send `{"Brandbekämpfung": "10", "Technische Hilfeleistung": "6", "Rettungsdienst": "239"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 07:13:16:127389 Send `{"Brandbekämpfung": "10", "Technische Hilfeleistung": "6", "Rettungsdienst": "245"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 07:23:34:944675 Send `{"Brandbekämpfung": "12", "Technische Hilfeleistung": "7", "Rettungsdienst": "251"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 07:43:11:699016 Send `{"Brandbekämpfung": "12", "Technische Hilfeleistung": "8", "Rettungsdienst": "264"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 07:53:31:379609 Send `{"Brandbekämpfung": "12", "Technische Hilfeleistung": "8", "Rettungsdienst": "268"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 08:03:51:067903 Send `{"Brandbekämpfung": "12", "Technische Hilfeleistung": "8", "Rettungsdienst": "277"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 08:14:10:600985 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "8", "Rettungsdienst": "288"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 08:24:30:925409 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "9", "Rettungsdienst": "298"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 08:44:07:197468 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "10", "Rettungsdienst": "310"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# 08:55:08:672004 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "10", "Rettungsdienst": "322"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 09:03:35:086675 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "10", "Rettungsdienst": "329"}` to topic `einsatzzahlen`
# 09:05:56:340960 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "10", "Rettungsdienst": "330"}` to topic `einsatzzahlen`
# 09:07:11:658929 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "10", "Rettungsdienst": "332"}` to topic `einsatzzahlen`
# 09:08:14:721473 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "10", "Rettungsdienst": "332"}` to topic `einsatzzahlen`
# 09:09:17:169917 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "10", "Rettungsdienst": "333"}` to topic `einsatzzahlen`
# 09:10:20:992659 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "10", "Rettungsdienst": "334"}` to topic `einsatzzahlen`
# 09:11:24:272435 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "10", "Rettungsdienst": "337"}` to topic `einsatzzahlen`
# 09:12:26:662619 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "337"}` to topic `einsatzzahlen`
# 09:13:30:566398 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "339"}` to topic `einsatzzahlen`
# 09:14:33:979848 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "340"}` to topic `einsatzzahlen`
# 09:15:37:072637 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "341"}` to topic `einsatzzahlen`
# 09:16:39:253160 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "343"}` to topic `einsatzzahlen`
# 09:17:41:665875 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "344"}` to topic `einsatzzahlen`
# 09:18:45:409783 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "344"}` to topic `einsatzzahlen`
# 09:19:47:414757 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "346"}` to topic `einsatzzahlen`
# 09:20:50:768756 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "346"}` to topic `einsatzzahlen`
# 09:32:27:839040 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "361"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 09:33:32:070128 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "364"}` to topic `einsatzzahlen`
# 09:34:35:568580 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "366"}` to topic `einsatzzahlen`
# 09:35:39:772372 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "368"}` to topic `einsatzzahlen`
# 09:36:44:280097 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "370"}` to topic `einsatzzahlen`
# 09:37:48:791636 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "371"}` to topic `einsatzzahlen`
# 09:38:53:939875 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "371"}` to topic `einsatzzahlen`
# 09:39:59:462937 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "373"}` to topic `einsatzzahlen`
# 09:41:03:789576 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "377"}` to topic `einsatzzahlen`
# 09:42:09:650576 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "378"}` to topic `einsatzzahlen`
# 09:43:18:006538 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "379"}` to topic `einsatzzahlen`
# 09:44:21:858831 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "380"}` to topic `einsatzzahlen`
# 09:45:29:177275 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "381"}` to topic `einsatzzahlen`
# 09:46:35:690192 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "382"}` to topic `einsatzzahlen`
# 09:47:44:706067 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "382"}` to topic `einsatzzahlen`
# 09:48:52:486457 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "382"}` to topic `einsatzzahlen`
# 09:50:00:408355 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "383"}` to topic `einsatzzahlen`
# 09:51:10:298375 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "11", "Rettungsdienst": "384"}` to topic `einsatzzahlen`
# 09:52:20:919273 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "12", "Rettungsdienst": "384"}` to topic `einsatzzahlen`
# 09:53:32:595807 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "12", "Rettungsdienst": "385"}` to topic `einsatzzahlen`
# 09:54:45:555188 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "12", "Rettungsdienst": "386"}` to topic `einsatzzahlen`
# 09:55:55:329025 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "12", "Rettungsdienst": "386"}` to topic `einsatzzahlen`
# 09:57:05:400927 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "12", "Rettungsdienst": "388"}` to topic `einsatzzahlen`
# 09:58:16:562701 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "12", "Rettungsdienst": "390"}` to topic `einsatzzahlen`
# 09:59:25:138841 Send `{"Brandbekämpfung": "13", "Technische Hilfeleistung": "12", "Rettungsdienst": "390"}` to topic `einsatzzahlen`
# 10:00:35:276718 Send `{"Brandbekämpfung": "14", "Technische Hilfeleistung": "12", "Rettungsdienst": "393"}` to topic `einsatzzahlen`
# 10:01:44:566722 Send `{"Brandbekämpfung": "15", "Technische Hilfeleistung": "12", "Rettungsdienst": "395"}` to topic `einsatzzahlen`
# 10:02:55:545766 Send `{"Brandbekämpfung": "15", "Technische Hilfeleistung": "12", "Rettungsdienst": "396"}` to topic `einsatzzahlen`
# 10:04:06:509446 Send `{"Brandbekämpfung": "15", "Technische Hilfeleistung": "12", "Rettungsdienst": "397"}` to topic `einsatzzahlen`
# 10:05:16:930380 Send `{"Brandbekämpfung": "15", "Technische Hilfeleistung": "12", "Rettungsdienst": "398"}` to topic `einsatzzahlen`
# 10:06:26:537981 Send `{"Brandbekämpfung": "15", "Technische Hilfeleistung": "12", "Rettungsdienst": "399"}` to topic `einsatzzahlen`
# 10:07:39:814269 Send `{"Brandbekämpfung": "15", "Technische Hilfeleistung": "13", "Rettungsdienst": "402"}` to topic `einsatzzahlen`
# 10:08:51:831855 Send `{"Brandbekämpfung": "15", "Technische Hilfeleistung": "13", "Rettungsdienst": "403"}` to topic `einsatzzahlen`
# 10:10:04:817046 Send `{"Brandbekämpfung": "15", "Technische Hilfeleistung": "13", "Rettungsdienst": "404"}` to topic `einsatzzahlen`
# 10:11:13:433642 Send `{"Brandbekämpfung": "15", "Technische Hilfeleistung": "13", "Rettungsdienst": "405"}` to topic `einsatzzahlen`
# 10:12:24:113832 Send `{"Brandbekämpfung": "15", "Technische Hilfeleistung": "13", "Rettungsdienst": "408"}` to topic `einsatzzahlen`
# 10:43:09:715791 Send `{"Brandbekämpfung": "15", "Technische Hilfeleistung": "15", "Rettungsdienst": "438"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# Connected to MQTT Broker!
# 11:00:47:499389 Send `{"Brandbekämpfung": "15", "Technische Hilfeleistung": "16", "Rettungsdienst": "461"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 11:17:30:858243 Send `{"Brandbekämpfung": "17", "Technische Hilfeleistung": "16", "Rettungsdienst": "479"}` to topic `einsatzzahlen`
# Connected to MQTT Broker!
# 11:38:29:769676 Send `{"Brandbekämpfung": "19", "Technische Hilfeleistung": "16", "Rettungsdienst": "501"}` to topic `einsatzzahlen`
# 11:39:42:196147 Send `{"Brandbekämpfung": "19", "Technische Hilfeleistung": "16", "Rettungsdienst": "503"}` to topic `einsatzzahlen`
# 11:40:57:940197 Send `{"Brandbekämpfung": "19", "Technische Hilfeleistung": "16", "Rettungsdienst": "505"}` to topic `einsatzzahlen`
# 11:42:02:484579 Send `{"Brandbekämpfung": "19", "Technische Hilfeleistung": "16", "Rettungsdienst": "506"}` to topic `einsatzzahlen`
# 11:43:06:817571 Send `{"Brandbekämpfung": "19", "Technische Hilfeleistung": "17", "Rettungsdienst": "508"}` to topic `einsatzzahlen`
# 11:44:25:288157 Send `{"Brandbekämpfung": "19", "Technische Hilfeleistung": "17", "Rettungsdienst": "508"}` to topic `einsatzzahlen`
# 11:45:28:018791 Send `{"Brandbekämpfung": "19", "Technische Hilfeleistung": "17", "Rettungsdienst": "510"}` to topic `einsatzzahlen`
# 11:46:30:875324 Send `{"Brandbekämpfung": "19", "Technische Hilfeleistung": "17", "Rettungsdienst": "513"}` to topic `einsatzzahlen`
# 11:47:46:662715 Send `{"Brandbekämpfung": "19", "Technische Hilfeleistung": "17", "Rettungsdienst": "513"}` to topic `einsatzzahlen`
# 11:48:57:717595 Send `{"Brandbekämpfung": "19", "Technische Hilfeleistung": "17", "Rettungsdienst": "513"}` to topic `einsatzzahlen`
# 11:50:06:844234 Send `{"Brandbekämpfung": "19", "Technische Hilfeleistung": "17", "Rettungsdienst": "514"}` to topic `einsatzzahlen`
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/threading.py", line 954, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/threading.py", line 892, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/andrehaberkorn/__Projekte__/Scrapper Einsätze/env/lib/python3.9/site-packages/paho/mqtt/client.py", line 3591, in _thread_main
#     self.loop_forever(retry_first_connection=True)
#   File "/Users/andrehaberkorn/__Projekte__/Scrapper Einsätze/env/lib/python3.9/site-packages/paho/mqtt/client.py", line 1756, in loop_forever
#     rc = self._loop(timeout)
#   File "/Users/andrehaberkorn/__Projekte__/Scrapper Einsätze/env/lib/python3.9/site-packages/paho/mqtt/client.py", line 1164, in _loop
#     rc = self.loop_read()
#   File "/Users/andrehaberkorn/__Projekte__/Scrapper Einsätze/env/lib/python3.9/site-packages/paho/mqtt/client.py", line 1556, in loop_read
#     rc = self._packet_read()
#   File "/Users/andrehaberkorn/__Projekte__/Scrapper Einsätze/env/lib/python3.9/site-packages/paho/mqtt/client.py", line 2370, in _packet_read
#     command = self._sock_recv(1)
#   File "/Users/andrehaberkorn/__Projekte__/Scrapper Einsätze/env/lib/python3.9/site-packages/paho/mqtt/client.py", line 640, in _sock_recv
#     return self._sock.recv(bufsize)
# TimeoutError: [Errno 60] Operation timed out
# 12:07:50:906320 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "18", "Rettungsdienst": "533"}` to topic `einsatzzahlen`
# 12:08:56:158014 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "18", "Rettungsdienst": "533"}` to topic `einsatzzahlen`
# 12:09:59:201008 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "18", "Rettungsdienst": "533"}` to topic `einsatzzahlen`
# 12:11:02:005819 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "18", "Rettungsdienst": "535"}` to topic `einsatzzahlen`
# 12:14:01:781676 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "19", "Rettungsdienst": "537"}` to topic `einsatzzahlen`
# 12:15:04:526003 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "19", "Rettungsdienst": "537"}` to topic `einsatzzahlen`
# 12:16:06:796142 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "19", "Rettungsdienst": "538"}` to topic `einsatzzahlen`
# 12:17:13:008200 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "19", "Rettungsdienst": "540"}` to topic `einsatzzahlen`
# 12:18:16:327221 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "19", "Rettungsdienst": "540"}` to topic `einsatzzahlen`
# 12:19:19:203887 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "20", "Rettungsdienst": "542"}` to topic `einsatzzahlen`
# 12:20:22:340749 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "20", "Rettungsdienst": "543"}` to topic `einsatzzahlen`
# 12:21:25:799550 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "20", "Rettungsdienst": "545"}` to topic `einsatzzahlen`
# 12:22:28:735218 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "20", "Rettungsdienst": "546"}` to topic `einsatzzahlen`
# 12:23:31:396671 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "20", "Rettungsdienst": "548"}` to topic `einsatzzahlen`
# 12:24:34:002462 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "20", "Rettungsdienst": "549"}` to topic `einsatzzahlen`
# 12:25:37:478560 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "20", "Rettungsdienst": "551"}` to topic `einsatzzahlen`
# 12:26:41:733230 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "20", "Rettungsdienst": "551"}` to topic `einsatzzahlen`
# 12:27:44:414769 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "20", "Rettungsdienst": "553"}` to topic `einsatzzahlen`
# 12:28:47:323569 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "20", "Rettungsdienst": "557"}` to topic `einsatzzahlen`
# 12:29:51:076918 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "20", "Rettungsdienst": "558"}` to topic `einsatzzahlen`
# 12:30:54:029759 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "20", "Rettungsdienst": "559"}` to topic `einsatzzahlen`
# 12:31:59:817658 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "23", "Rettungsdienst": "560"}` to topic `einsatzzahlen`
# 12:33:02:631772 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "23", "Rettungsdienst": "561"}` to topic `einsatzzahlen`
# 12:34:05:887965 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "23", "Rettungsdienst": "562"}` to topic `einsatzzahlen`
# 12:35:10:381777 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "24", "Rettungsdienst": "565"}` to topic `einsatzzahlen`
# 12:36:14:318404 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "24", "Rettungsdienst": "566"}` to topic `einsatzzahlen`
# 12:37:19:497854 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "24", "Rettungsdienst": "566"}` to topic `einsatzzahlen`
# 12:38:25:753487 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "24", "Rettungsdienst": "567"}` to topic `einsatzzahlen`
# 12:39:29:911988 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "24", "Rettungsdienst": "567"}` to topic `einsatzzahlen`
# 12:40:34:767418 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "24", "Rettungsdienst": "569"}` to topic `einsatzzahlen`
# 12:41:37:510366 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "24", "Rettungsdienst": "569"}` to topic `einsatzzahlen`
# 12:42:41:061066 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "26", "Rettungsdienst": "570"}` to topic `einsatzzahlen`
# 12:43:44:116903 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "26", "Rettungsdienst": "570"}` to topic `einsatzzahlen`
# 12:44:46:898788 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "26", "Rettungsdienst": "572"}` to topic `einsatzzahlen`
# 12:45:50:494742 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "26", "Rettungsdienst": "573"}` to topic `einsatzzahlen`
# 12:46:53:322887 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "26", "Rettungsdienst": "574"}` to topic `einsatzzahlen`
# 12:47:56:433604 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "26", "Rettungsdienst": "575"}` to topic `einsatzzahlen`
# 12:49:00:572891 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "26", "Rettungsdienst": "577"}` to topic `einsatzzahlen`
# 12:50:03:784821 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "26", "Rettungsdienst": "578"}` to topic `einsatzzahlen`
# 12:51:07:797830 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "27", "Rettungsdienst": "579"}` to topic `einsatzzahlen`
# 12:52:10:589932 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "27", "Rettungsdienst": "580"}` to topic `einsatzzahlen`
# 12:53:13:860699 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "27", "Rettungsdienst": "581"}` to topic `einsatzzahlen`
# 12:54:16:893901 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "27", "Rettungsdienst": "581"}` to topic `einsatzzahlen`
# 12:55:19:521811 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "27", "Rettungsdienst": "583"}` to topic `einsatzzahlen`
# 12:56:23:471060 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "27", "Rettungsdienst": "584"}` to topic `einsatzzahlen`
# 12:57:29:082466 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "27", "Rettungsdienst": "585"}` to topic `einsatzzahlen`
# 12:58:31:686559 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "27", "Rettungsdienst": "586"}` to topic `einsatzzahlen`
# 12:59:35:001805 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "27", "Rettungsdienst": "586"}` to topic `einsatzzahlen`
# 13:00:39:199630 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "27", "Rettungsdienst": "589"}` to topic `einsatzzahlen`
# 13:01:42:049616 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "27", "Rettungsdienst": "591"}` to topic `einsatzzahlen`
# 13:02:45:337746 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "27", "Rettungsdienst": "594"}` to topic `einsatzzahlen`
# 13:03:48:181019 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "27", "Rettungsdienst": "596"}` to topic `einsatzzahlen`
# 13:04:51:359240 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "27", "Rettungsdienst": "597"}` to topic `einsatzzahlen`
# 13:05:55:357027 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "28", "Rettungsdienst": "598"}` to topic `einsatzzahlen`
# 13:06:58:373585 Send `{"Brandbekämpfung": "20", "Technische Hilfeleistung": "29", "Rettungsdienst": "601"}` to topic `einsatzzahlen`
# 13:08:00:998774 Send `{"Brandbekämpfung": "21", "Technische Hilfeleistung": "29", "Rettungsdienst": "602"}` to topic `einsatzzahlen`
# 13:09:03:919741 Send `{"Brandbekämpfung": "21", "Technische Hilfeleistung": "29", "Rettungsdienst": "602"}` to topic `einsatzzahlen`
# 13:10:06:983759 Send `{"Brandbekämpfung": "21", "Technische Hilfeleistung": "29", "Rettungsdienst": "602"}` to topic `einsatzzahlen`
# 13:11:11:178093 Send `{"Brandbekämpfung": "21", "Technische Hilfeleistung": "29", "Rettungsdienst": "603"}` to topic `einsatzzahlen`
# 13:12:15:644805 Send `{"Brandbekämpfung": "21", "Technische Hilfeleistung": "29", "Rettungsdienst": "604"}` to topic `einsatzzahlen`
# 13:13:20:171113 Send `{"Brandbekämpfung": "21", "Technische Hilfeleistung": "29", "Rettungsdienst": "605"}` to topic `einsatzzahlen`
# 13:14:26:329407 Send `{"Brandbekämpfung": "21", "Technische Hilfeleistung": "29", "Rettungsdienst": "609"}` to topic `einsatzzahlen`
# 13:15:31:394762 Send `{"Brandbekämpfung": "21", "Technische Hilfeleistung": "29", "Rettungsdienst": "611"}` to topic `einsatzzahlen`
# 13:16:35:520540 Send `{"Brandbekämpfung": "21", "Technische Hilfeleistung": "29", "Rettungsdienst": "615"}` to topic `einsatzzahlen`
# 13:17:43:488589 Send `{"Brandbekämpfung": "21", "Technische Hilfeleistung": "29", "Rettungsdienst": "617"}` to topic `einsatzzahlen`
# 13:18:51:056878 Send `{"Brandbekämpfung": "21", "Technische Hilfeleistung": "29", "Rettungsdienst": "618"}` to topic `einsatzzahlen`
# 13:19:56:793803 Send `{"Brandbekämpfung": "21", "Technische Hilfeleistung": "29", "Rettungsdienst": "620"}` to topic `einsatzzahlen`
# 13:21:06:333103 Send `{"Brandbekämpfung": "21", "Technische Hilfeleistung": "29", "Rettungsdienst": "620"}` to topic `einsatzzahlen`
# 13:22:11:469723 Send `{"Brandbekämpfung": "21", "Technische Hilfeleistung": "29", "Rettungsdienst": "621"}` to topic `einsatzzahlen`
# 13:23:14:978920 Send `{"Brandbekämpfung": "21", "Technische Hilfeleistung": "29", "Rettungsdienst": "621"}` to topic `einsatzzahlen`
# 13:24:18:641767 Send `{"Brandbekämpfung": "21", "Technische Hilfeleistung": "29", "Rettungsdienst": "621"}` to topic `einsatzzahlen`
# 13:25:21:658846 Send `{"Brandbekämpfung": "22", "Technische Hilfeleistung": "29", "Rettungsdienst": "622"}` to topic `einsatzzahlen`
# 13:26:25:760972 Send `{"Brandbekämpfung": "22", "Technische Hilfeleistung": "29", "Rettungsdienst": "624"}` to topic `einsatzzahlen`
# 13:27:29:026863 Send `{"Brandbekämpfung": "22", "Technische Hilfeleistung": "29", "Rettungsdienst": "628"}` to topic `einsatzzahlen`
# 13:28:32:687207 Send `{"Brandbekämpfung": "22", "Technische Hilfeleistung": "29", "Rettungsdienst": "629"}` to topic `einsatzzahlen`
# 13:29:35:436380 Send `{"Brandbekämpfung": "22", "Technische Hilfeleistung": "29", "Rettungsdienst": "630"}` to topic `einsatzzahlen`
# 13:30:39:967842 Send `{"Brandbekämpfung": "22", "Technische Hilfeleistung": "29", "Rettungsdienst": "630"}` to topic `einsatzzahlen`
# 13:31:43:519108 Send `{"Brandbekämpfung": "22", "Technische Hilfeleistung": "29", "Rettungsdienst": "631"}` to topic `einsatzzahlen`
# 13:32:46:671257 Send `{"Brandbekämpfung": "22", "Technische Hilfeleistung": "29", "Rettungsdienst": "632"}` to topic `einsatzzahlen`
# 13:33:49:977194 Send `{"Brandbekämpfung": "22", "Technische Hilfeleistung": "29", "Rettungsdienst": "632"}` to topic `einsatzzahlen`
# 13:34:53:387796 Send `{"Brandbekämpfung": "22", "Technische Hilfeleistung": "30", "Rettungsdienst": "633"}` to topic `einsatzzahlen`
# 13:35:57:006497 Send `{"Brandbekämpfung": "22", "Technische Hilfeleistung": "30", "Rettungsdienst": "635"}` to topic `einsatzzahlen`
# 13:37:00:446880 Send `{"Brandbekämpfung": "22", "Technische Hilfeleistung": "30", "Rettungsdienst": "635"}` to topic `einsatzzahlen`
# 13:38:04:981655 Send `{"Brandbekämpfung": "22", "Technische Hilfeleistung": "30", "Rettungsdienst": "637"}` to topic `einsatzzahlen`
# 13:39:16:913636 Send `{"Brandbekämpfung": "22", "Technische Hilfeleistung": "30", "Rettungsdienst": "641"}` to topic `einsatzzahlen`
# 13:40:20:029791 Send `{"Brandbekämpfung": "22", "Technische Hilfeleistung": "30", "Rettungsdienst": "643"}` to topic `einsatzzahlen`
# 13:41:23:944559 Send `{"Brandbekämpfung": "22", "Technische Hilfeleistung": "30", "Rettungsdienst": "643"}` to topic `einsatzzahlen`
# 13:42:26:126564 Send `{"Brandbekämpfung": "22", "Technische Hilfeleistung": "30", "Rettungsdienst": "645"}` to topic `einsatzzahlen`
# 13:43:28:203690 Send `{"Brandbekämpfung": "22", "Technische Hilfeleistung": "30", "Rettungsdienst": "645"}` to topic `einsatzzahlen`
# 13:44:35:846384 Send `{"Brandbekämpfung": "22", "Technische Hilfeleistung": "30", "Rettungsdienst": "645"}` to topic `einsatzzahlen`
# 13:45:48:556716 Send `{"Brandbekämpfung": "22", "Technische Hilfeleistung": "30", "Rettungsdienst": "646"}` to topic `einsatzzahlen`
